# %%
import numpy as np
import matplotlib.pyplot as plt

Cities = np.loadtxt("Ex9_1_Cities.csv", delimiter = ',')
Cities_Coord = Cities[:, 1:]

Path = np.loadtxt("Ex9_1_Solution.csv", delimiter = ',')
Path_Coord = []

for i in Path:
    Path_Coord.append([Cities_Coord[int(i) - 1, 0], Cities_Coord[int(i) - 1, 1]])
Path_Coord.append([Cities_Coord[0, 0], Cities_Coord[0, 1]])
    
Path_Coord = np.asarray(Path_Coord)

# %%
plt.scatter(Cities_Coord[:,0], Cities_Coord[:,1])
plt.plot(Path_Coord[:,0], Path_Coord[:,1], 'r--')
plt.show()

# %%
Cities = np.loadtxt("Ex9_2_Cities.csv", delimiter = ',')
Cities_Coord = Cities[:, 1:]

Path = np.loadtxt("Ex9_2_Solution.csv", delimiter = ',')
Path_Coord = []

for i in Path:
    Path_Coord.append([Cities_Coord[int(i) - 1, 0], Cities_Coord[int(i) - 1, 1]])
Path_Coord.append([Cities_Coord[0, 0], Cities_Coord[0, 1]])
    
Path_Coord = np.asarray(Path_Coord)

# %%
plt.scatter(Cities_Coord[:,0], Cities_Coord[:,1])
plt.plot(Path_Coord[:,0], Path_Coord[:,1], 'r--')
plt.show()
