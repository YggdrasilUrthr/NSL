# %%
import numpy as np
import matplotlib.pyplot as plt

direct_data = np.loadtxt("Ex3_1.csv", delimiter=',')

fig, axs = plt.subplots(1, 2)

for i in range(0, 2):

    axs[i].errorbar(np.arange(1,101,1), direct_data[:,i], yerr=direct_data[:,i+1])

    axs[i].grid(True)

plt.plot()
# Out:
# []
